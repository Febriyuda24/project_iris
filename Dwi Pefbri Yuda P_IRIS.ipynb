# %% [markdown]
# ## Instruksi
# 1. Copy colab file ke drive masing-masing
# 1. Rename file colab dengan format : NAMA_LENGKAP_DATASET.ipynb
# 1. Lengkapi bagian kode
# 1. Berikan dokumentasi pada setiap cell kode
# ---

# %% [markdown]
# ### Import Seluruh Kebutuhan Library

# %%
# kode
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

import matplotlib as mpl

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.0.3

# %% [markdown]
# ### Load Dataset dan Tampilkan Isi Data
# * load data dapat dilakukan melalui unggah file lokal maupun unduh data dari url ([contoh](https://colab.research.google.com/drive/1YP6BQpJKotuR61vPdv4-Ap-oFdqhDuJj))
# * print standar, maupun menggunakan pandas

# %%
"""
 meload data pada file lokal iris.csv yang dan membuatnya dataframe df. 
 df.head diggunakan untuk menampilkan data 5 teratas dan melihatnya apakah sudah benar dan layak digunakan
  
  
"""

# kode
from sklearn.datasets import load_iris

# import some data to play with
iris = load_iris()

df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2     0.0
# 1                4.9               3.0  ...               0.2     0.0
# 2                4.7               3.2  ...               0.2     0.0
# 3                4.6               3.1  ...               0.2     0.0
# 4                5.0               3.6  ...               0.2     0.0
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Praproses Data
# * cek jika terdapat record / field yang tidak layak dipakai
# * lakukan praproses terhadap data-data tersebut

# %%
"""
  Menampilkan data iris dengan .info .head .columns gunanya untuk mengetahui data
  apakah sudah sesuai atau perlu dilakukan preprosesing data dan data iris sudah siap untuk di lakukan model
  
"""

# kode
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# target               150 non-null float64
# dtypes: float64(5)
# memory usage: 5.9 KB

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2     0.0
# 1                4.9               3.0  ...               0.2     0.0
# 2                4.7               3.2  ...               0.2     0.0
# 3                4.6               3.1  ...               0.2     0.0
# 4                5.0               3.6  ...               0.2     0.0
#
# [5 rows x 5 columns]

# %%
X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
       'petal width (cm)']]
y= df['target']

# %%
print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %% [markdown]
# ### Visualisasikan Data
# * Tampilkan visualisasi sederhana seperti plot, barchart, dll. [*hint*](https://matplotlib.org/3.1.0/tutorials/introductory/pyplot.html)

# %%
"""
  melakukan visualisasi data dengan histogram untuk melihat korelasi antara julah data 
  target dengan sepal lengt cm
  
"""

# kode

df['sepal length (cm)'].plot(kind='hist', figsize=(8, 5), color='blue')

plt.title('Histogram of IRIS ') # add a title to the histogram
plt.ylabel('target') # add y-label
plt.xlabel('sepal length (cm)') # add x-label

plt.show()

# %% [markdown]
# ### Bagi Data
# * bagi data menjadi data latih dan data uji
# * pembagian membagi variabel data dan label
# * bisa menggunakan library sklearn

# %%
"""
   membagi data uji dan data test sebanyak 80% dan data test 20%
  
"""

# kode

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=101, test_size = 0.2)

# %% [markdown]
# ### Latih Model Pembelajaran Mesin
# * Gunakan classifier yang sesuai dengan yang diperintahkan dalam [***project description***](https://drive.google.com/open?id=158T8j6uasWUfb-O9ta9l8PayIllwWcax).

# %%
"""
  mengolah data test yang diambil dari nilai X kemudia di lihat lagi apakah 
 jumlah datanya sama atau tudak jika tidak maka akan dilakukan normalilsasi
 data lagi,,
 disini 
  
"""

# kode

X_train 
y_train
X_test = X_test[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
       'petal width (cm)']]

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 33 to 41
# Data columns (total 4 columns):
# sepal length (cm)    30 non-null float64
# sepal width (cm)     30 non-null float64
# petal length (cm)    30 non-null float64
# petal width (cm)     30 non-null float64
# dtypes: float64(4)
# memory usage: 1.2 KB

# %% [markdown]
# ### Uji Hasil Model
# * Gunakan model yang telah kalian latih untuk melakukan prediksi menggunakan data uji.

# %%
"""
  data telah jadi dan sama maka dilakukan fit sebelum di predict
  menggunakan library linier model menggunakan data train
  
"""

# kode

from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=4).fit(X_train, y_train)

# %% [markdown]
# ### Evaluasi Performa: Confusion Matrix
# * Tampilkan evaluasi performa dari model yang dibangun menggunakan [***Confusion Matrix***](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)

# %%
"""
   mengolah data menjadi Y pred dari data X test menggunakan library data logistic
  model
  
"""

# kode

y_pred = knn_model.predict(X_test)

# %%
y_pred
# Out:
# array([0., 0., 0., 2., 1., 1., 1., 1., 1., 0., 2., 0., 0., 2., 2., 1., 1.,
#        1., 0., 2., 1., 0., 1., 1., 1., 1., 1., 2., 0., 0.])

# %%
y_test.values
# Out:
# array([0., 0., 0., 2., 1., 2., 1., 1., 2., 0., 2., 0., 0., 2., 2., 1., 1.,
#        1., 0., 2., 1., 0., 1., 1., 1., 1., 1., 2., 0., 0.])

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_pred, y_test))
# Out:
# [[10  0  0]
#  [ 0 12  2]
#  [ 0  0  6]]

# %% [markdown]
# ### Evaluasi Performa: Akurasi dan F1 Score
# * Tampilkan evaluasi performa dari model yang dibangun menggunakan [**Akurasi**](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html) dan [**F1 Score**](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html)

# %%
"""
  mencari akurasi 
  
"""

# kode

from sklearn.metrics import mean_absolute_error,accuracy_score, f1_score, classification_report


print("Mean absolute error: %.2f" % mean_absolute_error(y_pred, y_test.values))
print("Test set Accuracy: ", accuracy_score(y_pred, y_test.values))
# Out:
# Mean absolute error: 0.07
# Test set Accuracy:  0.9333333333333333

# %%
y_te
# Out:
# 33     0.0
# 16     0.0
# 43     0.0
# 129    2.0
# 50     1.0
# 123    2.0
# 68     1.0
# 53     1.0
# 146    2.0
# 1      0.0
# 147    2.0
# 32     0.0
# 31     0.0
# 122    2.0
# 127    2.0
# 74     1.0
# 88     1.0
# 96     1.0
# 42     0.0
# 134    2.0
# 80     1.0
# 48     0.0
# 90     1.0
# 65     1.0
# 97     1.0
# 64     1.0
# 93     1.0
# 114    2.0
# 25     0.0
# 41     0.0
# Name: target, dtype: float64

# %% [markdown]
# ### Visualisasi Hasil dan Performa
# * Tampilkan visualisasi performa dari model yang dibuat

# %%
"""
  dokumentasi
  
"""

# kode
from sklearn.metrics import classification_report, confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predict')

# %%
cdf = confusion_matrix(y_pred, y_test)
plt.figure()
plot_confusion_matrix(cdf, classes=['Versicolor=0','Virginica=1','Setosa=2'],normalize= False,  title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0 12  2]
#  [ 0  0  6]]
